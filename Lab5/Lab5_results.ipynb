# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Bài 1: Xây dựng mô hình Transformer Encoder gồm 3 lớp theo mô tả trong nghiên cứu [Attention is all you need](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf). Huấn luyện mô hình này cho bài toán phân loại domain câu bình luận trên bộ dữ liệu [UIT-ViOCD](https://drive.google.com/drive/folders/1Lu9axyLkw7dMx80uLRgvCnZsmNzhJWAa?usp=sharing).

# %%
# !cd /content/drive/MyDrive/DS201/Lab5/Bai1
# Out:
# /content/drive/MyDrive/DS201/Lab5/Bai1

# %%
# !python main.py
# Out:
# Using device: cuda
# Vocab size: 5084
# Model parameters: 3,410,948
# Epoch 1 - Training: 100% 275/275 [00:05<00:00, 54.49it/s, loss=0.766]
# Epoch 1 - Evaluating: 100% 35/35 [00:00<00:00, 244.44it/s]
# Epoch 1 | Loss: 0.7662 | Acc: 0.8394
# Saved best model (acc=0.8394)
# Epoch 2 - Training: 100% 275/275 [00:03<00:00, 72.01it/s, loss=0.554]
# Epoch 2 - Evaluating: 100% 35/35 [00:00<00:00, 251.58it/s]
# Epoch 2 | Loss: 0.5456 | Acc: 0.8412
# Saved best model (acc=0.8412)
# Epoch 3 - Training: 100% 275/275 [00:03<00:00, 69.75it/s, loss=0.496]
# Epoch 3 - Evaluating: 100% 35/35 [00:00<00:00, 187.65it/s]
# Epoch 3 | Loss: 0.4946 | Acc: 0.8631
# Saved best model (acc=0.8631)
# Epoch 4 - Training: 100% 275/275 [00:04<00:00, 60.31it/s, loss=0.467]
# Epoch 4 - Evaluating: 100% 35/35 [00:00<00:00, 257.54it/s]
# Epoch 4 | Loss: 0.4653 | Acc: 0.7901
# Epoch 5 - Training: 100% 275/275 [00:04<00:00, 62.39it/s, loss=0.483]
# Epoch 5 - Evaluating: 100% 35/35 [00:00<00:00, 232.43it/s]
# Epoch 5 | Loss: 0.4774 | Acc: 0.8704
# Saved best model (acc=0.8704)
# Epoch 6 - Training: 100% 275/275 [00:04<00:00, 59.19it/s, loss=0.44]
# Epoch 6 - Evaluating: 100% 35/35 [00:00<00:00, 123.16it/s]
# Epoch 6 | Loss: 0.4320 | Acc: 0.8303
# Epoch 7 - Training: 100% 275/275 [00:04<00:00, 55.40it/s, loss=0.417]
# Epoch 7 - Evaluating: 100% 35/35 [00:00<00:00, 261.29it/s]
# Epoch 7 | Loss: 0.4171 | Acc: 0.8777
# Saved best model (acc=0.8777)
# Epoch 8 - Training: 100% 275/275 [00:03<00:00, 69.65it/s, loss=0.441]
# Epoch 8 - Evaluating: 100% 35/35 [00:00<00:00, 255.06it/s]
# Epoch 8 | Loss: 0.4365 | Acc: 0.8577
# Epoch 9 - Training: 100% 275/275 [00:04<00:00, 63.58it/s, loss=0.477]
# Epoch 9 - Evaluating: 100% 35/35 [00:00<00:00, 168.47it/s]
# Epoch 9 | Loss: 0.4740 | Acc: 0.8175
# Epoch 10 - Training: 100% 275/275 [00:04<00:00, 61.88it/s, loss=0.5]
# Epoch 10 - Evaluating: 100% 35/35 [00:00<00:00, 221.49it/s]
# Epoch 10 | Loss: 0.4963 | Acc: 0.8631
#
# Training done. Best Accuracy = 0.8777

# %% [markdown]
# ### Bài 2: Xây dựng mô hình Transformer Encoder gồm 3 lớp theo mô tả trong nghiên cứu [Attention is all you need](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf). Huấn luyện mô hình này cho bài toán gán nhãn chuỗi trên bộ dữ liệu [PhoNERT](https://github.com/VinAIResearch/PhoNER_COVID19).

# %%
cd /content/drive/MyDrive/DS201/Lab5/Bai2
# Out:
# /content/drive/MyDrive/DS201/Lab5/Bai2

# %%
# !python /content/drive/MyDrive/DS201/Lab5/Bai2/main.py
# Out:
# Using device: cuda
# Train size: 5027
# Dev size: 2000
# Vocab size: 5243
# Num tags: 21
# Model params: 4,506,645
# Epoch 1 - Training: 100% 315/315 [00:04<00:00, 65.61it/s, loss=0.681]
# Epoch 1 - Evaluating: 100% 125/125 [00:00<00:00, 210.53it/s]
# Epoch 1 | Train loss: 0.6790 | Dev acc: 0.8446
# Saved best model (acc: 0.8446)
# Epoch 2 - Training: 100% 315/315 [00:04<00:00, 63.41it/s, loss=0.372]
# Epoch 2 - Evaluating: 100% 125/125 [00:01<00:00, 114.17it/s]
# Epoch 2 | Train loss: 0.3657 | Dev acc: 0.8801
# Saved best model (acc: 0.8801)
# Epoch 3 - Training: 100% 315/315 [00:04<00:00, 70.83it/s, loss=0.273]
# Epoch 3 - Evaluating: 100% 125/125 [00:00<00:00, 229.82it/s]
# Epoch 3 | Train loss: 0.2690 | Dev acc: 0.8935
# Saved best model (acc: 0.8935)
# Epoch 4 - Training: 100% 315/315 [00:04<00:00, 72.85it/s, loss=0.218]
# Epoch 4 - Evaluating: 100% 125/125 [00:00<00:00, 202.34it/s]
# Epoch 4 | Train loss: 0.2149 | Dev acc: 0.9086
# Saved best model (acc: 0.9086)
# Epoch 5 - Training: 100% 315/315 [00:05<00:00, 60.85it/s, loss=0.182]
# Epoch 5 - Evaluating: 100% 125/125 [00:00<00:00, 238.63it/s]
# Epoch 5 | Train loss: 0.1782 | Dev acc: 0.9146
# Saved best model (acc: 0.9146)
# Epoch 6 - Training: 100% 315/315 [00:04<00:00, 71.12it/s, loss=0.151]
# Epoch 6 - Evaluating: 100% 125/125 [00:00<00:00, 222.17it/s]
# Epoch 6 | Train loss: 0.1497 | Dev acc: 0.9249
# Saved best model (acc: 0.9249)
# Epoch 7 - Training: 100% 315/315 [00:05<00:00, 59.74it/s, loss=0.128]
# Epoch 7 - Evaluating: 100% 125/125 [00:00<00:00, 233.05it/s]
# Epoch 7 | Train loss: 0.1272 | Dev acc: 0.9274
# Saved best model (acc: 0.9274)
# Epoch 8 - Training: 100% 315/315 [00:04<00:00, 71.12it/s, loss=0.113]
# Epoch 8 - Evaluating: 100% 125/125 [00:00<00:00, 238.73it/s]
# Epoch 8 | Train loss: 0.1104 | Dev acc: 0.9313
# Saved best model (acc: 0.9313)
# Epoch 9 - Training: 100% 315/315 [00:04<00:00, 66.28it/s, loss=0.0963]
# Epoch 9 - Evaluating: 100% 125/125 [00:00<00:00, 179.24it/s]
# Epoch 9 | Train loss: 0.0963 | Dev acc: 0.9320
# Saved best model (acc: 0.9320)
# Epoch 10 - Training: 100% 315/315 [00:04<00:00, 66.21it/s, loss=0.0861]
# Epoch 10 - Evaluating: 100% 125/125 [00:00<00:00, 229.91it/s]
# Epoch 10 | Train loss: 0.0845 | Dev acc: 0.9344
# Saved best model (acc: 0.9344)
# Training completed! Best dev accuracy: 0.9344
